# %% [markdown]
# <a href="https://colab.research.google.com/github/Hunter-R-S/MAT494/blob/main/Probability2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MAT 494 - HW 6 - Probability (2)**

# %% [markdown]
# The code below is meant to exmplify points on continuous distributions.
#
# The contents come from QuantEcon's lecture series.

# %% [markdown]
# First, imports:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline

# %% [markdown]
# Starting with a normal distribution:

# %%
x = np.linspace(-5, 5, 100)

pdf_x = st.norm(0.0, 1.0).pdf(x)

fig, ax = plt.subplots()

ax.set_title(r"Normal Distribution ($\mu = 0, \sigma = 1$)")
ax.plot(x, pdf_x)

# %% [markdown]
# Next, a gamma distribution across a set of variables theta and k:

# %%
def plot_gamma(k, theta, x, ax=None):
    if ax is None:
        _, ax = plt.subplots()

    pdf_x = st.gamma(k, scale=theta).pdf(x)
    ax.plot(x, pdf_x, label=f"k = {k}  theta = {theta}")

    return ax

fig, ax = plt.subplots(figsize=(10, 6))
x = np.linspace(0.1, 20, 130)
plot_gamma(2.0, 1.0, x, ax)
plot_gamma(3.0, 1.0, x, ax)
plot_gamma(3.0, 2.0, x, ax)
plot_gamma(3.0, 0.5, x, ax)
ax.set_ylim((0, 0.6))
ax.set_xlim((0, 20))
ax.legend();
